# %%
# Import Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Make a reference to the books.csv file path
csv_path = "LoanStats_2018Q1.csv"

# %%
consol_debtQ1 = pd.read_csv(csv_path, encoding="utf-8", low_memory=False, skipinitialspace=True)
consol_debtQ1.head()
# Out:
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv       term  \
# 0  NaN        NaN    30000.0      30000.0          30000.0  36 months
# 1  NaN        NaN    34825.0      34825.0          34825.0  60 months
# 2  NaN        NaN     2600.0       2600.0           2600.0  36 months
# 3  NaN        NaN    20000.0      20000.0          20000.0  60 months
# 4  NaN        NaN    17000.0      17000.0          17000.0  60 months
#
#   int_rate  installment grade sub_grade       ...         \
# 0    7.34%       930.99     A        A4       ...
# 1   12.61%       785.45     C        C1       ...
# 2    7.96%        81.43     A        A5       ...
# 3    9.92%       424.16     B        B2       ...
# 4   20.39%       454.10     D        D4       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# ...

# %%
list(consol_debtQ1)
# Out:
# ['id',
#  'member_id',
#  'loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'url',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'collections_12_mths_ex_med',
#  'mths_since_last_major_derog',
#  'policy_code',
#  'application_type',
# ...

# %%
debt_column = consol_debtQ1[["issue_d", "purpose", "addr_state", "earliest_cr_line", "emp_length","annual_inc", "tot_cur_bal",
                            "home_ownership", "int_rate"]]
debt_column.head(50)
# Out:
#    issue_d             purpose addr_state earliest_cr_line emp_length  \
# 0   18-Mar               house         TX            9-Oct    3 years
# 1   18-Mar         credit_card         AZ            3-Jan    2 years
# 2   18-Mar               other         MI           11-Aug    3 years
# 3   18-Mar    home_improvement         VA            1-Jan    3 years
# 4   18-Mar  debt_consolidation         FL           Apr-99  10+ years
# 5   18-Mar               other         OK            9-Jan    8 years
# 6   18-Mar  debt_consolidation         FL           Oct-87        NaN
# 7   18-Mar               other         CA           Aug-95    5 years
# 8   18-Mar  debt_consolidation         FL           Jul-98    2 years
# 9   18-Mar  debt_consolidation         OR            3-Sep  10+ years
# 10  18-Mar         credit_card         PA           10-May     1 year
# 11  18-Mar      major_purchase         WA           Jan-98    9 years
# ...

# %%
csv_path = "LoanStats_2018Q2.csv"

# %%
consol_debtQ2 = pd.read_csv(csv_path, encoding="utf-8", low_memory=False, skipinitialspace=True)
consol_debtQ2.head()
# Out:
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv       term  \
# 0  NaN        NaN    12000.0      12000.0          12000.0  60 months
# 1  NaN        NaN    29150.0      29150.0          29150.0  60 months
# 2  NaN        NaN    20000.0      20000.0          20000.0  60 months
# 3  NaN        NaN    36000.0      36000.0          36000.0  60 months
# 4  NaN        NaN     5200.0       5200.0           5200.0  36 months
#
#   int_rate  installment grade sub_grade       ...         \
# 0   20.39%       320.54     D        D4       ...
# 1   20.39%       778.64     D        D4       ...
# 2   26.77%       607.97     E        E5       ...
# 3   10.07%       766.14     B        B2       ...
# 4   13.06%       175.36     C        C1       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# ...

# %%
debt_column2 = consol_debtQ2[["issue_d", "purpose", "addr_state", "earliest_cr_line", "emp_length","annual_inc", "tot_cur_bal",
                            "home_ownership", "int_rate"]]
debt_column2.head()
# Out:
#   issue_d             purpose addr_state earliest_cr_line emp_length  \
# 0  Jun-18         credit_card         OH           Nov-07  10+ years
# 1  Jun-18    home_improvement         CO           Feb-03  10+ years
# 2  Jun-18  debt_consolidation         GA           Mar-03  10+ years
# 3  Jun-18  debt_consolidation         GA           Feb-99   < 1 year
# 4  Jun-18  debt_consolidation         TX           Jun-06  10+ years
#
#    annual_inc  tot_cur_bal home_ownership int_rate
# 0     42000.0      11968.0           RENT   20.39%
# 1     51000.0     177088.0       MORTGAGE   20.39%
# 2     65000.0      45906.0       MORTGAGE   26.77%
# 3    145000.0     473776.0       MORTGAGE   10.07%
# 4     32000.0      73613.0           RENT   13.06%

# %%
csv_path = "LoanStats_2018Q3.csv"

# %%
consol_debtQ3 = pd.read_csv(csv_path, encoding="utf-8", low_memory=False, skipinitialspace=True)
consol_debtQ3.head()
# Out:
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv       term  \
# 0  NaN        NaN    10000.0      10000.0          10000.0  36 months
# 1  NaN        NaN    35000.0      35000.0          35000.0  60 months
# 2  NaN        NaN     9600.0       9600.0           9600.0  36 months
# 3  NaN        NaN    18000.0      18000.0          18000.0  36 months
# 4  NaN        NaN    12000.0      12000.0          12000.0  36 months
#
#   int_rate  installment grade sub_grade       ...         \
# 0    6.67%       307.27     A        A2       ...
# 1   11.55%       770.63     B        B4       ...
# 2    7.84%       300.13     A        A4       ...
# 3    7.21%       557.52     A        A3       ...
# 4    8.46%       378.59     A        A5       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# ...

# %%
debt_column3 = consol_debtQ3[["issue_d", "purpose", "addr_state", "earliest_cr_line", "emp_length","annual_inc", "tot_cur_bal",
                            "home_ownership", "int_rate"]]
debt_column3.head()
# Out:
#   issue_d             purpose addr_state earliest_cr_line emp_length  \
# 0  Sep-18         credit_card         NJ           Nov-93  10+ years
# 1  Sep-18  debt_consolidation         NJ           Jan-89  10+ years
# 2  Sep-18         credit_card         WI           Sep-04    3 years
# 3  Sep-18  debt_consolidation         FL           Jan-05  10+ years
# 4  Sep-18  debt_consolidation         NY           Aug-05    3 years
#
#    annual_inc  tot_cur_bal home_ownership int_rate
# 0     55000.0      34400.0       MORTGAGE    6.67%
# 1    200000.0     602115.0       MORTGAGE   11.55%
# 2     90000.0     257106.0       MORTGAGE    7.84%
# 3     70000.0     364400.0       MORTGAGE    7.21%
# 4     36500.0      24368.0           RENT    8.46%

# %%
csv_path = "LoanStats_2018Q4.csv"

# %%
consol_debtQ4 = pd.read_csv(csv_path, encoding="utf-8", low_memory=False, skipinitialspace=True)
consol_debtQ4.head()
# Out:
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv       term  \
# 0  NaN        NaN     2500.0       2500.0           2500.0  36 months
# 1  NaN        NaN    30000.0      30000.0          30000.0  60 months
# 2  NaN        NaN     5000.0       5000.0           5000.0  36 months
# 3  NaN        NaN     4000.0       4000.0           4000.0  36 months
# 4  NaN        NaN    30000.0      30000.0          30000.0  60 months
#
#   int_rate  installment grade sub_grade       ...         \
# 0   13.56%        84.92     C        C1       ...
# 1   18.94%       777.23     D        D2       ...
# 2   17.97%       180.69     D        D1       ...
# 3   18.94%       146.51     D        D2       ...
# 4   16.14%       731.78     C        C4       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# ...

# %%
debt_column4 = consol_debtQ4[["issue_d", "purpose", "addr_state", "earliest_cr_line", "emp_length","annual_inc", "tot_cur_bal",
                            "home_ownership", "int_rate"]]
debt_column4.head()
# Out:
#   issue_d             purpose addr_state earliest_cr_line emp_length  \
# 0  Dec-18  debt_consolidation         NY           Apr-01  10+ years
# 1  Dec-18  debt_consolidation         LA           Jun-87  10+ years
# 2  Dec-18  debt_consolidation         MI           Apr-11    6 years
# 3  Dec-18  debt_consolidation         WA           Feb-06  10+ years
# 4  Dec-18  debt_consolidation         MD           Dec-00  10+ years
#
#    annual_inc  tot_cur_bal home_ownership int_rate
# 0     55000.0      16901.0           RENT   13.56%
# 1     90000.0     321915.0       MORTGAGE   18.94%
# 2     59280.0     110299.0       MORTGAGE   17.97%
# 3     92000.0     305049.0       MORTGAGE   18.94%
# 4     57250.0     116007.0       MORTGAGE   16.14%

# %%
debt_column_all = pd.concat([debt_column, debt_column2, debt_column3, debt_column4])
debt_column_all
# Out:
#        issue_d             purpose addr_state earliest_cr_line emp_length  \
# 0       18-Mar               house         TX            9-Oct    3 years
# 1       18-Mar         credit_card         AZ            3-Jan    2 years
# 2       18-Mar               other         MI           11-Aug    3 years
# 3       18-Mar    home_improvement         VA            1-Jan    3 years
# 4       18-Mar  debt_consolidation         FL           Apr-99  10+ years
# 5       18-Mar               other         OK            9-Jan    8 years
# 6       18-Mar  debt_consolidation         FL           Oct-87        NaN
# 7       18-Mar               other         CA           Aug-95    5 years
# 8       18-Mar  debt_consolidation         FL           Jul-98    2 years
# 9       18-Mar  debt_consolidation         OR            3-Sep  10+ years
# 10      18-Mar         credit_card         PA           10-May     1 year
# 11      18-Mar      major_purchase         WA           Jan-98    9 years
# ...

# %%
#dir(debt_column_all)
#debt_column_all.annual_inc.dtype
debt_column_all.issue_d.dtype
# Out:
# dtype('O')

# %%
#debt_column_all["month"] = pd.to_datetime(debt_column_all["issue_d"])
debt_purpose = debt_column_all['purpose'].value_counts()
debt_purpose
#avg_fare_y = merge_table.groupby(['type', 'city'])['fare'].mean()
#avg_fare_y
# Out:
# debt_consolidation    259642
# credit_card           127702
# other                  35018
# home_improvement       32748
# major_purchase         11622
# medical                 6622
# house                   5430
# car                     4979
# small_business          4583
# vacation                3501
# moving                  3115
# renewable_energy         275
# wedding                    5
# Name: purpose, dtype: int64

# %%
#borrow_type = [13000, 26000, 52000, 30000, 9000]
#x_axis = np.arange(debt_purpose)
#x_axis

# %%
debt_purpose.plot.bar()
plt.show()

# %%
debt_compare = debt_column_all.loc[debt_column_all['purpose'] == "debt_consolidation"]
debt_compare.head()
# Out:
#    issue_d             purpose addr_state earliest_cr_line emp_length  \
# 4   18-Mar  debt_consolidation         FL           Apr-99  10+ years
# 6   18-Mar  debt_consolidation         FL           Oct-87        NaN
# 8   18-Mar  debt_consolidation         FL           Jul-98    2 years
# 9   18-Mar  debt_consolidation         OR            3-Sep  10+ years
# 13  18-Mar  debt_consolidation         NY           14-Aug     1 year
#
#     annual_inc  tot_cur_bal home_ownership int_rate
# 4      52000.0      18039.0           RENT   20.39%
# 6      19000.0      17709.0       MORTGAGE   10.41%
# 8     196000.0     534954.0            OWN    9.92%
# 9      50000.0     243513.0       MORTGAGE    6.07%
# 13     42000.0      14533.0           RENT    7.96%

# %%
plt.figure(figsize=(20,5)) 
plt.scatter(debt_compare['int_rate'], debt_compare['annual_inc'], marker="o", facecolors="blue")
plt.show()

# %%
#Pie Chart
    home_type = debt_compare['home_ownership'].value_counts()
    home_type
# Out:
# MORTGAGE    126282
# RENT        103628
# OWN          29474
# ANY            258
# Name: home_ownership, dtype: int64

# %%
home_type.plot.pie(
           shadow=False,
           explode=(0.15, 0, 0.15, 0),   
           startangle=90,
           autopct='%1.1f%%')

plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
region_debt = debt_compare['addr_state'].value_counts()
region_debt
# Out:
# CA    35247
# TX    21394
# NY    19498
# FL    19364
# IL    10017
# NJ     9273
# GA     8762
# OH     8384
# PA     8314
# NC     7393
# VA     7029
# MI     6628
# AZ     6407
# MD     6388
# MA     5949
# CO     5864
# WA     5476
# TN     4401
# IN     4366
# MN     4245
# CT     4209
# MO     4194
# NV     3990
# SC     3517
# WI     3392
# OR     3277
# AL     3111
# LA     2646
# KY     2511
# OK     2391
# KS     2086
# AR     1933
# UT     1740
# MS     1731
# WV     1534
# NM     1356
# NH     1330
# NE     1292
# RI     1242
# HI     1184
# ID      980
# ME      855
# DE      792
# MT      715
# VT      604
# AK      566
# ND      553
# SD      524
# WY      523
# DC      465
# Name: addr_state, dtype: int64

# %%
#Region 1: Northeast
#Division 1: New England (Connecticut, Maine, Massachusetts, New Hampshire, Rhode Island, and Vermont)
#Division 2: Mid-Atlantic (New Jersey, New York, and Pennsylvania)

#newdf = debt_compare[debt_compare["addr_state"] == "CA"]
#newdf
north_east = ["NE", "CT", "ME", "MA", "NH", "RI", "VT", "NJ", "NY", "PA"]
north_east
# Out:
# ['NE', 'CT', 'ME', 'MA', 'NH', 'RI', 'VT', 'NJ', 'NY', 'PA']

# %%
#Region 2: Midwest (Prior to June 1984, the Midwest Region was designated as the North Central Region
#Division 3: East North Central (Illinois, Indiana, Michigan, Ohio, and Wisconsin)
#Division 4: West North Central (Iowa, Kansas, Minnesota, Missouri, Nebraska, North Dakota, and South Dakota)
mid_west = ["IL", ""]

# %%
Region 3: South
Division 5: South Atlantic (Delaware, Florida, Georgia, Maryland, North Carolina, South Carolina, Virginia, District of Columbia, and West Virginia)
Division 6: East South Central (Alabama, Kentucky, Mississippi, and Tennessee)
Division 7: West South Central (Arkansas, Louisiana, Oklahoma, and Texas)

# %%
Region 4: West
Division 8: Mountain (Arizona, Colorado, Idaho, Montana, Nevada, New Mexico, Utah, and Wyoming)
Division 9: Pacific (Alaska, California, Hawaii, Oregon, and Washington)
